# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Ravindrathalari06/flyrank-internship-ml/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# ML-03 Section 1: verify the selected task type

task_type = "ranking / scoring"

print("Task type:", task_type)
print("Decision:", "Which content pages should be investigated first?")
# Out:
# Task type: ranking / scoring
# Decision: Which content pages should be investigated first?

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# ML-03 Section 2: inspect the available target/proxy fields
import pandas as pd
from datasets import load_dataset
import pandas as pd

dataset = load_dataset("FlyRank/internship-starter")
df = dataset["train"].to_pandas()

print("Target/proxy fields:")
print("trend_direction values:", df["trend_direction"].unique())
print("trend_pct range:", df["trend_pct"].min(), "to", df["trend_pct"].max())
# Out:
# Target/proxy fields:
# trend_direction values: ['down' 'stable' 'new' 'up' 'flat']
# trend_pct range: -100.0 to 44900.0

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# ML-03 Section 3: verify the ranking evaluation setup

metric = "Precision@K"

print("Success metric:", metric)
print("Task type:", "ranking / scoring")
print("Evaluation basis:", "Top-K prioritized content items")
print("K:", "To be fixed before model training")
# Out:
# Success metric: Precision@K
# Task type: ranking / scoring
# Evaluation basis: Top-K prioritized content items
# K: To be fixed before model training

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

from datasets import load_dataset
import pandas as pd
dataset = load_dataset("FlyRank/internship-starter")

df = dataset["train"].to_pandas()
print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Unique content IDs:", df["content_id"].nunique())

print("\nOne row represents one content item.")
display(df[["content_id", "client_id", "content_type", "trend_direction", "trend_pct"]].head())
# Out:
# Rows: 30000
# Columns: 53
# Unique content IDs: 30000
#
# One row represents one content item.
#              content_id          client_id     content_type trend_direction  \
# 0  content_304f48230142  client_f369cb89fc  keyword article            down
# 1  content_a1fb4e703a9e  client_4e07408562  keyword article            down
# 2  content_9aa793d4d895  client_7f2253d7e2  keyword article            down
# 3  content_331d6c4de07b  client_19581e27de  keyword article          stable
# 4  content_d99b7a2d90ca  client_3fdba35f04  keyword article            down
#
#    trend_pct
# 0      -41.4
# 1      -57.7
# 2      -60.9
# 3      -13.8
# 4      -34.7

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# ML-03 Section 5: show the range of signals available
signals = [
    "search_volume",
    "impressions_90d",
    "clicks_90d",
    "sessions_90d",
    "content_age_days",
    "days_since_last_update",
    "ctr",
    "avg_position",
    "engagement_rate"
]

print("Number of candidate signals:", len(signals))
print("Candidate signals:")
print(signals)
# Out:
# Number of candidate signals: 9
# Candidate signals:
# ['search_volume', 'impressions_90d', 'clicks_90d', 'sessions_90d', 'content_age_days', 'days_since_last_update', 'ctr', 'avg_position', 'engagement_rate']

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
