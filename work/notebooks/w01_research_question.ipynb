# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Ravindrathalari06/flyrank-internship-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Section 1: Lane and motivation are documented in the Markdown cell above.
print("Lane: Content Decay / Content Prioritization")
# Out:
# Lane: Content Decay / Content Prioritization

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Section 2: Decision, action, and cost are documented in the Markdown cell above.
decision = "Prioritize content pages for investigation and optimization"
actor = "FlyRank content/SEO team"
wrong_call_cost = "Wasted effort or missed problematic content"

print("Decision:", decision)
print("Who acts:", actor)
print("Cost of wrong call:", wrong_call_cost)
# Out:
# Decision: Prioritize content pages for investigation and optimization
# Who acts: FlyRank content/SEO team
# Cost of wrong call: Wasted effort or missed problematic content

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load starter dataset
url = "https://raw.githubusercontent.com/Ravindrathalari06/flyrank-internship-ml/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)

# Basic dataset size
total_content = len(df)

# Recent performance coverage
recent_data_count = df["impressions_last_30d"].notna().sum()

# Descriptive trend count
down_count = (df["trend_direction"] == "down").sum()
down_percentage = down_count / total_content * 100

print(f"Total content items: {total_content:,}")
print(f"Content items with recent impression data: {recent_data_count:,}")
print(f"Content items currently marked as down: {down_count:,} ({down_percentage:.2f}%)")
# Out:
# Total content items: 30,000
# Content items with recent impression data: 30,000
# Content items currently marked as down: 16,262 (54.21%)

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Section 4: Claim boundaries
allowed_claims = [
    "observed",
    "measured",
    "directional",
    "decision-support"
]

not_claimed = [
    "causal proof",
    "predicting Google",
    "guaranteed future performance"
]

print("Allowed claim types:", ", ".join(allowed_claims))
print("Claims not made:", ", ".join(not_claimed))
# Out:
# Allowed claim types: observed, measured, directional, decision-support
# Claims not made: causal proof, predicting Google, guaranteed future performance

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
